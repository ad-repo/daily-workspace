# %% [markdown]
# # Running vLLM
#
# This provides the model endpoint needed for Q&A generation in the InstructLab pipeline.

# %% [markdown]
# ## Install vLLM

# %%
# Install vLLM
# !pip install vllm huggingface-hub python-dotenv
# Out:
# Requirement already satisfied: vllm in /opt/app-root/lib64/python3.12/site-packages (0.10.2)
# Requirement already satisfied: huggingface-hub in /opt/app-root/lib64/python3.12/site-packages (0.35.1)
# Requirement already satisfied: python-dotenv in /opt/app-root/lib64/python3.12/site-packages (1.1.1)
# Requirement already satisfied: regex in /opt/app-root/lib64/python3.12/site-packages (from vllm) (2025.9.18)
# Requirement already satisfied: cachetools in /opt/app-root/lib64/python3.12/site-packages (from vllm) (6.2.0)
# Requirement already satisfied: psutil in /opt/app-root/lib64/python3.12/site-packages (from vllm) (7.0.0)
# Requirement already satisfied: sentencepiece in /opt/app-root/lib64/python3.12/site-packages (from vllm) (0.2.1)
# Requirement already satisfied: numpy in /opt/app-root/lib64/python3.12/site-packages (from vllm) (2.2.6)
# Requirement already satisfied: requests>=2.26.0 in /opt/app-root/lib64/python3.12/site-packages (from vllm) (2.32.4)
# Requirement already satisfied: tqdm in /opt/app-root/lib64/python3.12/site-packages (from vllm) (4.67.1)
# Requirement already satisfied: blake3 in /opt/app-root/lib64/python3.12/site-packages (from vllm) (1.0.6)
# Requirement already satisfied: py-cpuinfo in /opt/app-root/lib64/python3.12/site-packages (from vllm) (9.0.0)
# Requirement already satisfied: transformers>=4.55.2 in /opt/app-root/lib64/python3.12/site-packages (from vllm) (4.56.2)
# Requirement already satisfied: tokenizers>=0.21.1 in /opt/app-root/lib64/python3.12/site-packages (from vllm) (0.22.1)
# Requirement already satisfied: protobuf in /opt/app-root/lib64/python3.12/site-packages (from vllm) (6.32.1)
# Requirement already satisfied: fastapi>=0.115.0 in /opt/app-root/lib64/python3.12/site-packages (from fastapi[standard]>=0.115.0->vllm) (0.118.0)
# Requirement already satisfied: aiohttp in /opt/app-root/lib64/python3.12/site-packages (from vllm) (3.12.14)
# Requirement already satisfied: openai>=1.99.1 in /opt/app-root/lib64/python3.12/site-packages (from vllm) (1.109.1)
# Requirement already satisfied: pydantic>=2.11.7 in /opt/app-root/lib64/python3.12/site-packages (from vllm) (2.11.9)
# Requirement already satisfied: prometheus_client>=0.18.0 in /opt/app-root/lib64/python3.12/site-packages (from vllm) (0.22.1)
# Requirement already satisfied: pillow in /opt/app-root/lib64/python3.12/site-packages (from vllm) (11.3.0)
# Requirement already satisfied: prometheus-fastapi-instrumentator>=7.0.0 in /opt/app-root/lib64/python3.12/site-packages (from vllm) (7.1.0)
# Requirement already satisfied: tiktoken>=0.6.0 in /opt/app-root/lib64/python3.12/site-packages (from vllm) (0.11.0)
# Requirement already satisfied: lm-format-enforcer==0.11.3 in /opt/app-root/lib64/python3.12/site-packages (from vllm) (0.11.3)
# Requirement already satisfied: llguidance<0.8.0,>=0.7.11 in /opt/app-root/lib64/python3.12/site-packages (from vllm) (0.7.30)
# Requirement already satisfied: outlines_core==0.2.11 in /opt/app-root/lib64/python3.12/site-packages (from vllm) (0.2.11)
# Requirement already satisfied: diskcache==5.6.3 in /opt/app-root/lib64/python3.12/site-packages (from vllm) (5.6.3)
# Requirement already satisfied: lark==1.2.2 in /opt/app-root/lib64/python3.12/site-packages (from vllm) (1.2.2)
# Requirement already satisfied: xgrammar==0.1.23 in /opt/app-root/lib64/python3.12/site-packages (from vllm) (0.1.23)
# Requirement already satisfied: typing_extensions>=4.10 in /opt/app-root/lib64/python3.12/site-packages (from vllm) (4.14.1)
# Requirement already satisfied: filelock>=3.16.1 in /opt/app-root/lib64/python3.12/site-packages (from vllm) (3.19.1)
# Requirement already satisfied: partial-json-parser in /opt/app-root/lib64/python3.12/site-packages (from vllm) (0.2.1.1.post6)
# Requirement already satisfied: pyzmq>=25.0.0 in /opt/app-root/lib64/python3.12/site-packages (from vllm) (27.0.0)
# Requirement already satisfied: msgspec in /opt/app-root/lib64/python3.12/site-packages (from vllm) (0.19.0)
# Requirement already satisfied: gguf>=0.13.0 in /opt/app-root/lib64/python3.12/site-packages (from vllm) (0.17.1)
# Requirement already satisfied: mistral_common>=1.8.2 in /opt/app-root/lib64/python3.12/site-packages (from mistral_common[audio,image]>=1.8.2->vllm) (1.8.5)
# Requirement already satisfied: opencv-python-headless>=4.11.0 in /opt/app-root/lib64/python3.12/site-packages (from vllm) (4.12.0.88)
# Requirement already satisfied: pyyaml in /opt/app-root/lib64/python3.12/site-packages (from vllm) (6.0.2)
# Requirement already satisfied: six>=1.16.0 in /opt/app-root/lib64/python3.12/site-packages (from vllm) (1.17.0)
# Requirement already satisfied: setuptools<80,>=77.0.3 in /opt/app-root/lib64/python3.12/site-packages (from vllm) (79.0.1)
# Requirement already satisfied: einops in /opt/app-root/lib64/python3.12/site-packages (from vllm) (0.8.1)
# Requirement already satisfied: compressed-tensors==0.11.0 in /opt/app-root/lib64/python3.12/site-packages (from vllm) (0.11.0)
# Requirement already satisfied: depyf==0.19.0 in /opt/app-root/lib64/python3.12/site-packages (from vllm) (0.19.0)
# Requirement already satisfied: cloudpickle in /opt/app-root/lib64/python3.12/site-packages (from vllm) (3.1.1)
# Requirement already satisfied: watchfiles in /opt/app-root/lib64/python3.12/site-packages (from vllm) (1.1.0)
# Requirement already satisfied: python-json-logger in /opt/app-root/lib64/python3.12/site-packages (from vllm) (3.3.0)
# Requirement already satisfied: scipy in /opt/app-root/lib64/python3.12/site-packages (from vllm) (1.16.2)
# Requirement already satisfied: ninja in /opt/app-root/lib64/python3.12/site-packages (from vllm) (1.13.0)
# Requirement already satisfied: pybase64 in /opt/app-root/lib64/python3.12/site-packages (from vllm) (1.4.2)
# Requirement already satisfied: cbor2 in /opt/app-root/lib64/python3.12/site-packages (from vllm) (5.7.0)
# Requirement already satisfied: setproctitle in /opt/app-root/lib64/python3.12/site-packages (from vllm) (1.3.7)
# Requirement already satisfied: openai-harmony>=0.0.3 in /opt/app-root/lib64/python3.12/site-packages (from vllm) (0.0.4)
# Requirement already satisfied: numba==0.61.2 in /opt/app-root/lib64/python3.12/site-packages (from vllm) (0.61.2)
# Requirement already satisfied: ray>=2.48.0 in /opt/app-root/lib64/python3.12/site-packages (from ray[cgraph]>=2.48.0->vllm) (2.49.2)
# Requirement already satisfied: torch==2.8.0 in /opt/app-root/lib64/python3.12/site-packages (from vllm) (2.8.0)
# Requirement already satisfied: torchaudio==2.8.0 in /opt/app-root/lib64/python3.12/site-packages (from vllm) (2.8.0)
# Requirement already satisfied: torchvision==0.23.0 in /opt/app-root/lib64/python3.12/site-packages (from vllm) (0.23.0)
# Requirement already satisfied: xformers==0.0.32.post1 in /opt/app-root/lib64/python3.12/site-packages (from vllm) (0.0.32.post1)
# Requirement already satisfied: frozendict in /opt/app-root/lib64/python3.12/site-packages (from compressed-tensors==0.11.0->vllm) (2.4.6)
# Requirement already satisfied: astor in /opt/app-root/lib64/python3.12/site-packages (from depyf==0.19.0->vllm) (0.8.1)
# Requirement already satisfied: dill in /opt/app-root/lib64/python3.12/site-packages (from depyf==0.19.0->vllm) (0.4.0)
# Requirement already satisfied: interegular>=0.3.2 in /opt/app-root/lib64/python3.12/site-packages (from lm-format-enforcer==0.11.3->vllm) (0.3.3)
# Requirement already satisfied: packaging in /opt/app-root/lib64/python3.12/site-packages (from lm-format-enforcer==0.11.3->vllm) (25.0)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /opt/app-root/lib64/python3.12/site-packages (from numba==0.61.2->vllm) (0.44.0)
# Requirement already satisfied: sympy>=1.13.3 in /opt/app-root/lib64/python3.12/site-packages (from torch==2.8.0->vllm) (1.14.0)
# Requirement already satisfied: networkx in /opt/app-root/lib64/python3.12/site-packages (from torch==2.8.0->vllm) (3.5)
# Requirement already satisfied: jinja2 in /opt/app-root/lib64/python3.12/site-packages (from torch==2.8.0->vllm) (3.1.6)
# Requirement already satisfied: fsspec in /opt/app-root/lib64/python3.12/site-packages (from torch==2.8.0->vllm) (2025.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /opt/app-root/lib64/python3.12/site-packages (from torch==2.8.0->vllm) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /opt/app-root/lib64/python3.12/site-packages (from torch==2.8.0->vllm) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /opt/app-root/lib64/python3.12/site-packages (from torch==2.8.0->vllm) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /opt/app-root/lib64/python3.12/site-packages (from torch==2.8.0->vllm) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /opt/app-root/lib64/python3.12/site-packages (from torch==2.8.0->vllm) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /opt/app-root/lib64/python3.12/site-packages (from torch==2.8.0->vllm) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /opt/app-root/lib64/python3.12/site-packages (from torch==2.8.0->vllm) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /opt/app-root/lib64/python3.12/site-packages (from torch==2.8.0->vllm) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /opt/app-root/lib64/python3.12/site-packages (from torch==2.8.0->vllm) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /opt/app-root/lib64/python3.12/site-packages (from torch==2.8.0->vllm) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /opt/app-root/lib64/python3.12/site-packages (from torch==2.8.0->vllm) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /opt/app-root/lib64/python3.12/site-packages (from torch==2.8.0->vllm) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /opt/app-root/lib64/python3.12/site-packages (from torch==2.8.0->vllm) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /opt/app-root/lib64/python3.12/site-packages (from torch==2.8.0->vllm) (1.13.1.3)
# Requirement already satisfied: triton==3.4.0 in /opt/app-root/lib64/python3.12/site-packages (from torch==2.8.0->vllm) (3.4.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /opt/app-root/lib64/python3.12/site-packages (from huggingface-hub) (1.1.10)
# Requirement already satisfied: starlette<0.49.0,>=0.40.0 in /opt/app-root/lib64/python3.12/site-packages (from fastapi>=0.115.0->fastapi[standard]>=0.115.0->vllm) (0.48.0)
# Requirement already satisfied: fastapi-cli>=0.0.8 in /opt/app-root/lib64/python3.12/site-packages (from fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (0.0.13)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in /opt/app-root/lib64/python3.12/site-packages (from fastapi[standard]>=0.115.0->vllm) (0.28.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /opt/app-root/lib64/python3.12/site-packages (from fastapi[standard]>=0.115.0->vllm) (0.0.20)
# Requirement already satisfied: email-validator>=2.0.0 in /opt/app-root/lib64/python3.12/site-packages (from fastapi[standard]>=0.115.0->vllm) (2.3.0)
# Requirement already satisfied: uvicorn>=0.12.0 in /opt/app-root/lib64/python3.12/site-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (0.37.0)
# Requirement already satisfied: jsonschema>=4.21.1 in /opt/app-root/lib64/python3.12/site-packages (from mistral_common>=1.8.2->mistral_common[audio,image]>=1.8.2->vllm) (4.24.0)
# Requirement already satisfied: pydantic-extra-types>=2.10.5 in /opt/app-root/lib64/python3.12/site-packages (from pydantic-extra-types[pycountry]>=2.10.5->mistral_common>=1.8.2->mistral_common[audio,image]>=1.8.2->vllm) (2.10.5)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/app-root/lib64/python3.12/site-packages (from openai>=1.99.1->vllm) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/app-root/lib64/python3.12/site-packages (from openai>=1.99.1->vllm) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /opt/app-root/lib64/python3.12/site-packages (from openai>=1.99.1->vllm) (0.11.0)
# Requirement already satisfied: sniffio in /opt/app-root/lib64/python3.12/site-packages (from openai>=1.99.1->vllm) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/app-root/lib64/python3.12/site-packages (from pydantic>=2.11.7->vllm) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /opt/app-root/lib64/python3.12/site-packages (from pydantic>=2.11.7->vllm) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/app-root/lib64/python3.12/site-packages (from pydantic>=2.11.7->vllm) (0.4.1)
# Requirement already satisfied: click>=7.0 in /opt/app-root/lib64/python3.12/site-packages (from ray>=2.48.0->ray[cgraph]>=2.48.0->vllm) (8.3.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /opt/app-root/lib64/python3.12/site-packages (from ray>=2.48.0->ray[cgraph]>=2.48.0->vllm) (1.1.1)
# Requirement already satisfied: cupy-cuda12x in /opt/app-root/lib64/python3.12/site-packages (from ray[cgraph]>=2.48.0->vllm) (13.6.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/app-root/lib64/python3.12/site-packages (from requests>=2.26.0->vllm) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/app-root/lib64/python3.12/site-packages (from requests>=2.26.0->vllm) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/app-root/lib64/python3.12/site-packages (from requests>=2.26.0->vllm) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/app-root/lib64/python3.12/site-packages (from requests>=2.26.0->vllm) (2025.7.14)
# Requirement already satisfied: safetensors>=0.4.3 in /opt/app-root/lib64/python3.12/site-packages (from transformers>=4.55.2->vllm) (0.6.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/app-root/lib64/python3.12/site-packages (from aiohttp->vllm) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/app-root/lib64/python3.12/site-packages (from aiohttp->vllm) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/app-root/lib64/python3.12/site-packages (from aiohttp->vllm) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/app-root/lib64/python3.12/site-packages (from aiohttp->vllm) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/app-root/lib64/python3.12/site-packages (from aiohttp->vllm) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /opt/app-root/lib64/python3.12/site-packages (from aiohttp->vllm) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/app-root/lib64/python3.12/site-packages (from aiohttp->vllm) (1.20.1)
# Requirement already satisfied: dnspython>=2.0.0 in /opt/app-root/lib64/python3.12/site-packages (from email-validator>=2.0.0->fastapi[standard]>=0.115.0->vllm) (2.8.0)
# Requirement already satisfied: typer>=0.15.1 in /opt/app-root/lib64/python3.12/site-packages (from fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (0.16.1)
# Requirement already satisfied: rich-toolkit>=0.14.8 in /opt/app-root/lib64/python3.12/site-packages (from fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (0.15.1)
# Requirement already satisfied: fastapi-cloud-cli>=0.1.1 in /opt/app-root/lib64/python3.12/site-packages (from fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (0.2.1)
# Requirement already satisfied: httpcore==1.* in /opt/app-root/lib64/python3.12/site-packages (from httpx<1.0.0,>=0.23.0->fastapi[standard]>=0.115.0->vllm) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/app-root/lib64/python3.12/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->fastapi[standard]>=0.115.0->vllm) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/app-root/lib64/python3.12/site-packages (from jinja2->torch==2.8.0->vllm) (3.0.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/app-root/lib64/python3.12/site-packages (from jsonschema>=4.21.1->mistral_common>=1.8.2->mistral_common[audio,image]>=1.8.2->vllm) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/app-root/lib64/python3.12/site-packages (from jsonschema>=4.21.1->mistral_common>=1.8.2->mistral_common[audio,image]>=1.8.2->vllm) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/app-root/lib64/python3.12/site-packages (from jsonschema>=4.21.1->mistral_common>=1.8.2->mistral_common[audio,image]>=1.8.2->vllm) (0.26.0)
# Requirement already satisfied: pycountry>=23 in /opt/app-root/lib64/python3.12/site-packages (from pydantic-extra-types[pycountry]>=2.10.5->mistral_common>=1.8.2->mistral_common[audio,image]>=1.8.2->vllm) (24.6.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/app-root/lib64/python3.12/site-packages (from sympy>=1.13.3->torch==2.8.0->vllm) (1.3.0)
# Requirement already satisfied: httptools>=0.6.3 in /opt/app-root/lib64/python3.12/site-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (0.6.4)
# Requirement already satisfied: uvloop>=0.15.1 in /opt/app-root/lib64/python3.12/site-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (0.21.0)
# Requirement already satisfied: websockets>=10.4 in /opt/app-root/lib64/python3.12/site-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (15.0.1)
# Requirement already satisfied: fastrlock>=0.5 in /opt/app-root/lib64/python3.12/site-packages (from cupy-cuda12x->ray[cgraph]>=2.48.0->vllm) (0.8.3)
# Requirement already satisfied: soundfile>=0.12.1 in /opt/app-root/lib64/python3.12/site-packages (from mistral_common>=1.8.2->mistral_common[audio,image]>=1.8.2->vllm) (0.13.1)
# Requirement already satisfied: soxr>=0.5.0 in /opt/app-root/lib64/python3.12/site-packages (from mistral_common>=1.8.2->mistral_common[audio,image]>=1.8.2->vllm) (1.0.0)
# Requirement already satisfied: rignore>=0.5.1 in /opt/app-root/lib64/python3.12/site-packages (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (0.6.4)
# Requirement already satisfied: sentry-sdk>=2.20.0 in /opt/app-root/lib64/python3.12/site-packages (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (2.39.0)
# Requirement already satisfied: rich>=13.7.1 in /opt/app-root/lib64/python3.12/site-packages (from rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (14.1.0)
# Requirement already satisfied: cffi>=1.0 in /opt/app-root/lib64/python3.12/site-packages (from soundfile>=0.12.1->mistral_common>=1.8.2->mistral_common[audio,image]>=1.8.2->vllm) (1.17.1)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/app-root/lib64/python3.12/site-packages (from typer>=0.15.1->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (1.5.4)
# Requirement already satisfied: pycparser in /opt/app-root/lib64/python3.12/site-packages (from cffi>=1.0->soundfile>=0.12.1->mistral_common>=1.8.2->mistral_common[audio,image]>=1.8.2->vllm) (2.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/app-root/lib64/python3.12/site-packages (from rich>=13.7.1->rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/app-root/lib64/python3.12/site-packages (from rich>=13.7.1->rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /opt/app-root/lib64/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=13.7.1->rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (0.1.2)
#
# [notice] A new release of pip is available: 24.2 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## Download Model

# %%
import os

# hf_repo = "RedHatAI/Llama-3.3-70B-Instruct-FP8-dynamic"
# hf_repo = "RedHatAI/gpt-oss-120b"
# hf_repo = "RedHatAI/phi-4-FP8-dynamic"
hf_repo = "RedHatAI/phi-4"
# hf_repo = "RedHatAI/gpt-oss-120b"


model_dir = f"/models/{hf_repo}"

# %%
# !mkdir -p $model_dir
# !huggingface-cli download $hf_repo --local-dir $model_dir
# Out:
# ⚠️  Warning: 'huggingface-cli download' is deprecated. Use 'hf download' instead.
# Fetching 20 files:   0%|                                 | 0/20 [00:00<?, ?it/s]Still waiting to acquire lock on /models/RedHatAI/phi-4/.cache/huggingface/.gitignore.lock (elapsed: 0.1 seconds)
# Still waiting to acquire lock on /models/RedHatAI/phi-4/.cache/huggingface/.gitignore.lock (elapsed: 0.1 seconds)
# Still waiting to acquire lock on /models/RedHatAI/phi-4/.cache/huggingface/.gitignore.lock (elapsed: 0.1 seconds)
# Still waiting to acquire lock on /models/RedHatAI/phi-4/.cache/huggingface/.gitignore.lock (elapsed: 0.1 seconds)
# Downloading 'LICENSE' to '/models/RedHatAI/phi-4/.cache/huggingface/download/DhCjcNQuMpl4FL346qr3tvNUCgY=.700edcc5f42c4816520bc554926ad7e0d9e613d7.incomplete'
# Downloading '.gitattributes' to '/models/RedHatAI/phi-4/.cache/huggingface/download/wPaCkH-WbT7GsmxMKKrNZTV4nSM=.a6344aac8c09253b3b630fb776ae94478aa0275b.incomplete'
# Downloading 'SECURITY.md' to '/models/RedHatAI/phi-4/.cache/huggingface/download/hSrnLtSfgijFBTW07bq7w-it8Jg=.6b906d43bc2057e6a832c3236897b2e514d6e1e7.incomplete'
# Downloading 'added_tokens.json' to '/models/RedHatAI/phi-4/.cache/huggingface/download/SeqzFlf9ZNZ3or_wZAOIdsM3Yxw=.c410491b4c95d889958ff4480f37ab235018a67f.incomplete'
# Downloading 'generation_config.json' to '/models/RedHatAI/phi-4/.cache/huggingface/download/3EVKVggOldJcKSsGjSdoUCN1AyQ=.acacd3d4755f432dd02147fe60a851121efcd4cc.incomplete'
# Downloading 'README.md' to '/models/RedHatAI/phi-4/.cache/huggingface/download/Xn7B-BWUGOee2Y6hCZtEhtFu4BE=.a68b8dbb270d29bcafef791243cc06b9a0343a49.incomplete'
# Downloading 'CODE_OF_CONDUCT.md' to '/models/RedHatAI/phi-4/.cache/huggingface/download/K98JAqu7X0Q8Wy3TIHRTrEErCiw=.c72a5749c52ac97bca71c672ef5295d303d22b05.incomplete'
# Downloading 'config.json' to '/models/RedHatAI/phi-4/.cache/huggingface/download/8_PA_wEVGiVa2goH2H4KQOQpvVY=.ab17e0b5838762a837102af7269223b5a20d52fd.incomplete'
#
# LICENSE: 1.10kB [00:00, 6.36MB/s]
# Download complete. Moving file to /models/RedHatAI/phi-4/LICENSE
#
# .gitattributes: 1.52kB [00:00, 7.69MB/s]
# Download complete. Moving file to /models/RedHatAI/phi-4/.gitattributes
# Fetching 20 files:   5%|█▎                       | 1/20 [00:00<00:12,  1.55it/s]
# SECURITY.md: 2.70kB [00:00, 13.8MB/s]
# Download complete. Moving file to /models/RedHatAI/phi-4/SECURITY.md
#
# generation_config.json: 100%|██████████████████| 156/156 [00:00<00:00, 1.87MB/s]
# Download complete. Moving file to /models/RedHatAI/phi-4/generation_config.json
#
# added_tokens.json: 0.00B [00:00, ?B/s]
#
# added_tokens.json: 2.50kB [00:00, 5.34MB/s]
# README.md: 19.9kB [00:00, 50.6MB/s]
# Download complete. Moving file to /models/RedHatAI/phi-4/added_tokens.json
# Download complete. Moving file to /models/RedHatAI/phi-4/README.md
#
# CODE_OF_CONDUCT.md: 100%|██████████████████████| 453/453 [00:00<00:00, 6.96MB/s]
# Download complete. Moving file to /models/RedHatAI/phi-4/CODE_OF_CONDUCT.md
#
# config.json: 100%|█████████████████████████████| 802/802 [00:00<00:00, 10.6MB/s]
# Download complete. Moving file to /models/RedHatAI/phi-4/config.json
# Downloading 'model-00001-of-00006.safetensors' to '/models/RedHatAI/phi-4/.cache/huggingface/download/lPnGVsdaF542Y6w1ufNAL-pphxo=.cafbe72210c39b19270cbfce27996afc4383c8a487087bcb91a6290d5ceb8f18.incomplete'
# Downloading 'model-00002-of-00006.safetensors' to '/models/RedHatAI/phi-4/.cache/huggingface/download/H1O8ZB_QwtWjsrLtliP4_68j6q4=.9f87a5897162ed988cfb0fac13879634b4bab3da5a756b4f9dd2437ef8145e20.incomplete'
# Downloading 'model-00003-of-00006.safetensors' to '/models/RedHatAI/phi-4/.cache/huggingface/download/XYxS_-gMKqyeF0pSwDVvLc_63Nc=.19537df78a263aa0c0b2dc12dbce5908021e30a25e528699b08642c3999eeb05.incomplete'
# Downloading 'model-00006-of-00006.safetensors' to '/models/RedHatAI/phi-4/.cache/huggingface/download/uHlhOCT17Z6wYlt1x1jlrCcHTyE=.a9bfeeea354e31503d09a864e6cd5bd0f1230664065b6a2988b05e22b3228d77.incomplete'
# Downloading 'model-00005-of-00006.safetensors' to '/models/RedHatAI/phi-4/.cache/huggingface/download/oSetzz1DFkf7L3TvpxdZ6YtuoKo=.a72666b6001d76e7a9dc3ebe0d05a2c3316f546a8c6779c87343f296bdf82e50.incomplete'
# Downloading 'model-00004-of-00006.safetensors' to '/models/RedHatAI/phi-4/.cache/huggingface/download/71f3TSsxAmosSx1AFSGJtFrSxfc=.d4f17100a39c19d352f2e8108eef6fb975afb86808e50d78a075e162f1edfc93.incomplete'
# Downloading 'merges.txt' to '/models/RedHatAI/phi-4/.cache/huggingface/download/PtHk0z_I45atnj23IIRhTExwT3w=.354558edcdbd64ca7abd407b8be3d5d09d39d781.incomplete'
#
# model-00001-of-00006.safetensors:   0%|             | 0.00/4.93G [00:00<?, ?B/s]
#
# model-00002-of-00006.safetensors:   0%|             | 0.00/4.95G [00:00<?, ?B/s]
#
#
# model-00003-of-00006.safetensors:   0%|             | 0.00/4.90G [00:00<?, ?B/s]Downloading 'model.safetensors.index.json' to '/models/RedHatAI/phi-4/.cache/huggingface/download/yVzAsSxRSINSz-tQbpx-TLpfkLU=.d9c4e28d4f7cc72949fdc86940c8a67583750436.incomplete'
#
#
#
#
# model-00005-of-00006.safetensors:   0%|             | 0.00/4.77G [00:00<?, ?B/s]
#
#
#
#
# model-00006-of-00006.safetensors:   0%|             | 0.00/4.99G [00:00<?, ?B/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:   0%|             | 0.00/4.77G [00:00<?, ?B/s]
#
#
#
#
#
#
# merges.txt: 0.00B [00:00, ?B/s]
#
#
#
#
#
#
#
# model.safetensors.index.json: 20.4kB [00:00, 92.8MB/s]A
# Download complete. Moving file to /models/RedHatAI/phi-4/model.safetensors.index.json
#
#
#
#
#
#
#
# merges.txt: 917kB [00:00, 7.11MB/s]
# Download complete. Moving file to /models/RedHatAI/phi-4/merges.txt
# Fetching 20 files:  45%|███████████▎             | 9/20 [00:01<00:01,  7.41it/s]Downloading 'special_tokens_map.json' to '/models/RedHatAI/phi-4/.cache/huggingface/download/ahkChHUJFxEmOdq5GDFEmerRzCY=.ea8cb2e2c57355312c3ff7b0e0f1beaf8e88ce8e.incomplete'
# Downloading 'tokenizer.json' to '/models/RedHatAI/phi-4/.cache/huggingface/download/HgM_lKo9sdSCfRtVg7MMFS7EKqo=.4cc07e6ec369bc5bdfd719da75f411373d8b436a.incomplete'
#
#
#
#
#
#
#
# special_tokens_map.json: 100%|███████████████| 95.0/95.0 [00:00<00:00, 1.36MB/s]
# Download complete. Moving file to /models/RedHatAI/phi-4/special_tokens_map.json
#
#
#
#
#
#
#
# tokenizer.json: 0.00B [00:00, ?B/s]
#
#
#
#
#
#
# tokenizer.json: 4.25MB [00:00, 21.4MB/s]
# Downloading 'tokenizer_config.json' to '/models/RedHatAI/phi-4/.cache/huggingface/download/vzaExXFZNBay89bvlQv-ZcI6BTg=.25c30b707a88b5e5fc715fb81d2221d1162380b4.incomplete'
# Download complete. Moving file to /models/RedHatAI/phi-4/tokenizer.json
#
#
#
#
#
#
#
# tokenizer_config.json: 17.7kB [00:00, 93.3MB/s]A
# Download complete. Moving file to /models/RedHatAI/phi-4/tokenizer_config.json
# Downloading 'vocab.json' to '/models/RedHatAI/phi-4/.cache/huggingface/download/j3m-Hy6QvBddw8RXA1uSWl1AJ0c=.c5dc46ce1c830966b5e947da6d471ea3c2e1e57e.incomplete'
#
#
# model-00002-of-00006.safetensors:   0%|    | 591k/4.95G [00:01<4:17:23, 321kB/s]
#
#
#
#
# model-00006-of-00006.safetensors:   0%|   | 1.37M/4.99G [00:01<1:53:15, 734kB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:   0%|   | 1.24M/4.77G [00:01<2:00:06, 662kB/s]
# model-00001-of-00006.safetensors:   1%|    | 67.1M/4.93G [00:02<02:29, 32.5MB/s]
#
#
#
#
#
#
# vocab.json: 0.00B [00:00, ?B/s]
#
# model-00002-of-00006.safetensors:   7%|▍     | 336M/4.95G [00:02<00:20, 222MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:   1%|    | 68.3M/4.77G [00:02<01:45, 44.6MB/s]
#
#
#
#
#
#
# vocab.json: 1.20MB [00:00, 11.9MB/s]
# model-00001-of-00006.safetensors:   8%|▍     | 403M/4.93G [00:02<00:18, 247MB/s]
#
# model-00002-of-00006.safetensors:   9%|▌     | 470M/4.95G [00:02<00:14, 316MB/s]
#
#
#
# vocab.json: 1.61MB [00:00, 9.32MB/s]0%|   | 1.46M/4.77G [00:02<1:58:32, 671kB/s]
# Download complete. Moving file to /models/RedHatAI/phi-4/vocab.json
#
# model-00001-of-00006.safetensors:  12%|▋     | 604M/4.93G [00:02<00:13, 332MB/s]
#
# model-00002-of-00006.safetensors:  12%|▋     | 604M/4.95G [00:02<00:15, 277MB/s]
#
#
#
# model-00005-of-00006.safetensors:   6%|▎     | 269M/4.77G [00:02<00:37, 120MB/s]
# model-00001-of-00006.safetensors:  15%|▉     | 738M/4.93G [00:03<00:14, 280MB/s]
#
# model-00002-of-00006.safetensors:  15%|▉     | 738M/4.95G [00:03<00:14, 285MB/s]
#
#
#
#
# model-00006-of-00006.safetensors:   1%|    | 68.4M/4.99G [00:03<03:23, 24.2MB/s]
#
#
# model-00003-of-00006.safetensors:   1%|    | 67.0M/4.90G [00:03<04:18, 18.7MB/s]
#
# model-00002-of-00006.safetensors:  16%|▉     | 805M/4.95G [00:03<00:16, 249MB/s]
#
#
#
# model-00005-of-00006.safetensors:  10%|▌     | 471M/4.77G [00:03<00:26, 162MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:   3%|▏    | 135M/4.77G [00:03<01:55, 40.0MB/s]
#
#
# model-00003-of-00006.safetensors:   3%|▏    | 134M/4.90G [00:03<02:02, 39.0MB/s]
#
# model-00002-of-00006.safetensors:  18%|█     | 872M/4.95G [00:04<00:18, 224MB/s]
#
#
#
# model-00005-of-00006.safetensors:  13%|▊     | 605M/4.77G [00:04<00:20, 201MB/s]
#
#
#
#
# model-00006-of-00006.safetensors:   3%|▏    | 135M/4.99G [00:04<01:54, 42.2MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:   4%|▏    | 202M/4.77G [00:04<01:10, 65.0MB/s]
#
#
# model-00003-of-00006.safetensors:   5%|▎    | 268M/4.90G [00:04<00:50, 92.5MB/s]
#
# model-00002-of-00006.safetensors:  19%|█▏    | 939M/4.95G [00:04<00:17, 230MB/s]
#
#
#
#
# model-00006-of-00006.safetensors:   4%|▏    | 202M/4.99G [00:04<01:10, 68.1MB/s]
# model-00001-of-00006.safetensors:  18%|█     | 872M/4.93G [00:04<00:22, 185MB/s]
#
# model-00002-of-00006.safetensors:  22%|█    | 1.07G/4.95G [00:04<00:13, 286MB/s]
#
#
#
# model-00005-of-00006.safetensors:  15%|▉     | 739M/4.77G [00:04<00:19, 211MB/s]
#
#
#
#
# model-00006-of-00006.safetensors:   5%|▎    | 269M/4.99G [00:04<00:50, 93.5MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:   7%|▍     | 336M/4.77G [00:04<00:40, 110MB/s]
# model-00001-of-00006.safetensors:  20%|█    | 1.01G/4.93G [00:04<00:17, 220MB/s]
#
# model-00002-of-00006.safetensors:  23%|█▏   | 1.14G/4.95G [00:04<00:13, 273MB/s]
#
#
#
# model-00005-of-00006.safetensors:  17%|█     | 806M/4.77G [00:04<00:18, 216MB/s]
#
#
#
#
# model-00006-of-00006.safetensors:   7%|▍     | 336M/4.99G [00:04<00:39, 118MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:   8%|▌     | 403M/4.77G [00:05<00:34, 128MB/s]
# model-00001-of-00006.safetensors:  22%|█    | 1.07G/4.93G [00:05<00:17, 218MB/s]
#
#
# model-00003-of-00006.safetensors:   7%|▎    | 335M/4.90G [00:05<00:52, 86.3MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:  10%|▌     | 470M/4.77G [00:05<00:32, 132MB/s]
# model-00001-of-00006.safetensors:  23%|█▏   | 1.14G/4.93G [00:05<00:19, 190MB/s]
#
#
# model-00003-of-00006.safetensors:   8%|▍    | 402M/4.90G [00:05<00:48, 92.2MB/s]
#
# model-00002-of-00006.safetensors:  26%|█▎   | 1.27G/4.95G [00:05<00:18, 203MB/s]
#
#
#
# model-00005-of-00006.safetensors:  20%|█▏    | 940M/4.77G [00:05<00:20, 183MB/s]
#
#
#
#
# model-00006-of-00006.safetensors:   8%|▍    | 403M/4.99G [00:05<00:48, 94.1MB/s]
#
# model-00002-of-00006.safetensors:  27%|█▎   | 1.34G/4.95G [00:06<00:18, 195MB/s]
#
#
#
# model-00005-of-00006.safetensors:  21%|█    | 1.01G/4.77G [00:06<00:20, 181MB/s]
#
#
#
#
# model-00006-of-00006.safetensors:  11%|▋     | 537M/4.99G [00:06<00:29, 153MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:  13%|▊     | 604M/4.77G [00:06<00:28, 145MB/s]
#
#
#
# model-00005-of-00006.safetensors:  23%|█▏   | 1.07G/4.77G [00:06<00:18, 199MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:  15%|▉     | 739M/4.77G [00:06<00:20, 197MB/s]
# model-00001-of-00006.safetensors:  26%|█▎   | 1.28G/4.93G [00:06<00:23, 156MB/s]
#
#
# model-00003-of-00006.safetensors:  10%|▍    | 469M/4.90G [00:06<00:55, 79.5MB/s]
#
# model-00002-of-00006.safetensors:  30%|█▍   | 1.48G/4.95G [00:06<00:18, 192MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:  18%|█     | 873M/4.77G [00:07<00:18, 214MB/s]
#
# model-00002-of-00006.safetensors:  31%|█▌   | 1.54G/4.95G [00:07<00:19, 178MB/s]
#
#
#
#
# model-00006-of-00006.safetensors:  12%|▋     | 604M/4.99G [00:07<00:40, 109MB/s]
# model-00001-of-00006.safetensors:  30%|█▍   | 1.48G/4.93G [00:07<00:18, 183MB/s]
#
#
# model-00003-of-00006.safetensors:  11%|▌    | 536M/4.90G [00:07<00:53, 81.6MB/s]
#
# model-00002-of-00006.safetensors:  32%|█▌   | 1.61G/4.95G [00:07<00:17, 190MB/s]
#
#
#
#
# model-00006-of-00006.safetensors:  15%|▉     | 739M/4.99G [00:07<00:26, 161MB/s]
#
#
#
# model-00005-of-00006.safetensors:  24%|█▏   | 1.14G/4.77G [00:07<00:30, 118MB/s]
# model-00001-of-00006.safetensors:  31%|█▌   | 1.54G/4.93G [00:07<00:17, 193MB/s]
#
#
# model-00003-of-00006.safetensors:  12%|▋     | 603M/4.90G [00:07<00:42, 102MB/s]
#
#
#
# model-00005-of-00006.safetensors:  25%|█▎   | 1.21G/4.77G [00:08<00:26, 134MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:  20%|█▏    | 940M/4.77G [00:08<00:25, 150MB/s]
#
#
# model-00003-of-00006.safetensors:  14%|▊     | 670M/4.90G [00:08<00:36, 117MB/s]
#
#
#
# model-00005-of-00006.safetensors:  28%|█▍   | 1.34G/4.77G [00:08<00:18, 190MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:  21%|█    | 1.01G/4.77G [00:08<00:23, 162MB/s]
#
#
# model-00003-of-00006.safetensors:  16%|▉     | 804M/4.90G [00:08<00:21, 192MB/s]
#
#
#
#
# model-00006-of-00006.safetensors:  16%|▉     | 806M/4.99G [00:08<00:31, 132MB/s]
#
#
#
# model-00005-of-00006.safetensors:  31%|█▌   | 1.48G/4.77G [00:08<00:12, 263MB/s]
#
# model-00002-of-00006.safetensors:  35%|█▊   | 1.74G/4.95G [00:08<00:18, 170MB/s]
#
#
#
#
# model-00006-of-00006.safetensors:  18%|█     | 873M/4.99G [00:08<00:27, 150MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:  23%|█▏   | 1.07G/4.77G [00:08<00:23, 156MB/s]
#
#
# model-00003-of-00006.safetensors:  18%|█     | 871M/4.90G [00:08<00:23, 175MB/s]
#
#
#
#
# model-00006-of-00006.safetensors:  19%|█▏    | 940M/4.99G [00:09<00:23, 171MB/s]
# model-00001-of-00006.safetensors:  33%|█▋   | 1.61G/4.93G [00:09<00:25, 132MB/s]
#
# model-00002-of-00006.safetensors:  38%|█▉   | 1.88G/4.95G [00:09<00:15, 197MB/s]
#
#
#
#
# model-00006-of-00006.safetensors:  20%|█    | 1.01G/4.99G [00:09<00:18, 214MB/s]
# model-00001-of-00006.safetensors:  35%|█▊   | 1.75G/4.93G [00:09<00:16, 191MB/s]
#
# model-00002-of-00006.safetensors:  39%|█▉   | 1.95G/4.95G [00:09<00:13, 220MB/s]
#
#
#
# model-00005-of-00006.safetensors:  32%|█▌   | 1.54G/4.77G [00:09<00:17, 183MB/s]
#
#
# model-00003-of-00006.safetensors:  19%|█▏    | 940M/4.90G [00:09<00:22, 175MB/s]
# model-00001-of-00006.safetensors:  37%|█▊   | 1.81G/4.93G [00:09<00:15, 201MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:  24%|█▏   | 1.14G/4.77G [00:09<00:25, 140MB/s]
#
#
#
# model-00005-of-00006.safetensors:  35%|█▊   | 1.68G/4.77G [00:09<00:12, 249MB/s]
#
#
#
#
# model-00006-of-00006.safetensors:  22%|█    | 1.07G/4.99G [00:09<00:21, 178MB/s]
# model-00001-of-00006.safetensors:  38%|█▉   | 1.88G/4.93G [00:09<00:15, 201MB/s]
#
# model-00002-of-00006.safetensors:  42%|██   | 2.08G/4.95G [00:09<00:12, 222MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:  25%|█▎   | 1.21G/4.77G [00:09<00:23, 154MB/s]
#
#
#
# model-00005-of-00006.safetensors:  37%|█▊   | 1.75G/4.77G [00:09<00:13, 227MB/s]
# model-00001-of-00006.safetensors:  39%|█▉   | 1.95G/4.93G [00:10<00:14, 201MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:  27%|█▎   | 1.27G/4.77G [00:10<00:21, 166MB/s]
#
# model-00002-of-00006.safetensors:  43%|██▏  | 2.15G/4.95G [00:10<00:13, 211MB/s]
#
#
#
# model-00005-of-00006.safetensors:  38%|█▉   | 1.81G/4.77G [00:10<00:13, 224MB/s]
#
#
# model-00003-of-00006.safetensors:  21%|█    | 1.01G/4.90G [00:10<00:31, 123MB/s]
#
#
#
#
# model-00006-of-00006.safetensors:  23%|█▏   | 1.14G/4.99G [00:10<00:27, 140MB/s]
# model-00001-of-00006.safetensors:  42%|██   | 2.08G/4.93G [00:10<00:15, 188MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:  28%|█▍   | 1.34G/4.77G [00:10<00:26, 132MB/s]
#
#
#
# model-00005-of-00006.safetensors:  41%|██   | 1.95G/4.77G [00:11<00:19, 144MB/s]
#
#
# model-00003-of-00006.safetensors:  22%|▉   | 1.07G/4.90G [00:11<00:45, 84.6MB/s]
#
#
#
#
# model-00006-of-00006.safetensors:  24%|▉   | 1.21G/4.99G [00:11<00:42, 89.3MB/s]
# model-00001-of-00006.safetensors:  44%|██▏  | 2.15G/4.93G [00:11<00:20, 135MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:  30%|█▍   | 1.41G/4.77G [00:11<00:33, 101MB/s]
#
#
# model-00003-of-00006.safetensors:  25%|█▏   | 1.21G/4.90G [00:12<00:29, 124MB/s]
#
#
#
#
# model-00006-of-00006.safetensors:  26%|█▎   | 1.27G/4.99G [00:12<00:36, 101MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:  31%|█▌   | 1.48G/4.77G [00:12<00:28, 115MB/s]
#
# model-00002-of-00006.safetensors:  45%|█▊  | 2.21G/4.95G [00:12<00:30, 90.6MB/s]
#
#
#
# model-00005-of-00006.safetensors:  42%|██   | 2.01G/4.77G [00:12<00:21, 129MB/s]
#
#
# model-00003-of-00006.safetensors:  26%|█▎   | 1.27G/4.90G [00:12<00:25, 142MB/s]
#
#
#
#
# model-00006-of-00006.safetensors:  28%|█▍   | 1.41G/4.99G [00:12<00:22, 160MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:  32%|█▌   | 1.54G/4.77G [00:12<00:23, 136MB/s]
#
# model-00002-of-00006.safetensors:  46%|██▎  | 2.28G/4.95G [00:12<00:26, 102MB/s]
#
#
# model-00003-of-00006.safetensors:  27%|█▎   | 1.34G/4.90G [00:12<00:24, 146MB/s]
#
#
#
#
# model-00006-of-00006.safetensors:  31%|█▌   | 1.54G/4.99G [00:12<00:17, 200MB/s]
# model-00001-of-00006.safetensors:  45%|██▏  | 2.21G/4.93G [00:13<00:26, 102MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:  35%|█▊   | 1.68G/4.77G [00:13<00:16, 187MB/s]
#
# model-00002-of-00006.safetensors:  47%|██▎  | 2.35G/4.95G [00:13<00:21, 119MB/s]
#
#
# model-00003-of-00006.safetensors:  29%|█▍   | 1.41G/4.90G [00:13<00:20, 167MB/s]
#
#
#
#
# model-00006-of-00006.safetensors:  32%|█▌   | 1.61G/4.99G [00:13<00:15, 213MB/s]
# model-00001-of-00006.safetensors:  46%|██▎  | 2.28G/4.93G [00:13<00:21, 123MB/s]
#
# model-00002-of-00006.safetensors:  49%|██▍  | 2.42G/4.95G [00:13<00:17, 142MB/s]
#
#
#
# model-00005-of-00006.safetensors:  44%|██▏  | 2.08G/4.77G [00:13<00:25, 107MB/s]
#
#
# model-00003-of-00006.safetensors:  30%|█▌   | 1.48G/4.90G [00:13<00:19, 174MB/s]
# model-00001-of-00006.safetensors:  49%|██▍  | 2.41G/4.93G [00:13<00:15, 166MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:  38%|█▉   | 1.81G/4.77G [00:13<00:15, 192MB/s]
#
# model-00002-of-00006.safetensors:  50%|██▌  | 2.49G/4.95G [00:13<00:17, 138MB/s]
#
#
#
# model-00005-of-00006.safetensors:  45%|██▎  | 2.15G/4.77G [00:13<00:23, 112MB/s]
#
#
# model-00003-of-00006.safetensors:  33%|█▋   | 1.61G/4.90G [00:13<00:15, 210MB/s]
#
#
#
#
# model-00006-of-00006.safetensors:  34%|█▋   | 1.68G/4.99G [00:13<00:21, 155MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:  39%|█▉   | 1.88G/4.77G [00:14<00:17, 166MB/s]
#
# model-00002-of-00006.safetensors:  52%|██▌  | 2.55G/4.95G [00:14<00:17, 137MB/s]
#
#
#
# model-00005-of-00006.safetensors:  48%|██▍  | 2.28G/4.77G [00:14<00:16, 149MB/s]
#
#
# model-00003-of-00006.safetensors:  34%|█▋   | 1.68G/4.90G [00:14<00:17, 185MB/s]
# model-00001-of-00006.safetensors:  50%|██▌  | 2.48G/4.93G [00:14<00:18, 133MB/s]
#
# model-00002-of-00006.safetensors:  53%|██▋  | 2.62G/4.95G [00:14<00:14, 161MB/s]
#
#
#
#
# model-00006-of-00006.safetensors:  35%|█▊   | 1.75G/4.99G [00:14<00:23, 135MB/s]
# model-00001-of-00006.safetensors:  53%|██▋  | 2.62G/4.93G [00:14<00:12, 192MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:  41%|██   | 1.95G/4.77G [00:14<00:17, 162MB/s]
#
#
#
# model-00005-of-00006.safetensors:  49%|██▍  | 2.35G/4.77G [00:14<00:17, 142MB/s]
#
#
#
#
# model-00006-of-00006.safetensors:  36%|█▊   | 1.81G/4.99G [00:15<00:21, 147MB/s]
#
# model-00002-of-00006.safetensors:  54%|██▋  | 2.69G/4.95G [00:15<00:16, 137MB/s]
#
#
# model-00003-of-00006.safetensors:  36%|█▊   | 1.75G/4.90G [00:15<00:23, 136MB/s]
#
#
#
#
# model-00006-of-00006.safetensors:  38%|█▉   | 1.88G/4.99G [00:15<00:21, 147MB/s]
# model-00001-of-00006.safetensors:  54%|██▋  | 2.68G/4.93G [00:15<00:15, 149MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:  42%|██   | 2.02G/4.77G [00:15<00:21, 131MB/s]
#
# model-00002-of-00006.safetensors:  57%|██▊  | 2.82G/4.95G [00:15<00:11, 192MB/s]
#
#
#
# model-00005-of-00006.safetensors:  55%|██▋  | 2.62G/4.77G [00:15<00:09, 218MB/s]
#
#
# model-00003-of-00006.safetensors:  38%|█▉   | 1.88G/4.90G [00:15<00:16, 185MB/s]
#
#
#
#
# model-00006-of-00006.safetensors:  39%|█▉   | 1.95G/4.99G [00:15<00:18, 165MB/s]
# model-00001-of-00006.safetensors:  57%|██▊  | 2.82G/4.93G [00:15<00:10, 203MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:  44%|██▏  | 2.08G/4.77G [00:15<00:18, 148MB/s]
#
#
#
# model-00005-of-00006.safetensors:  56%|██▊  | 2.68G/4.77G [00:16<00:11, 180MB/s]
#
#
# model-00003-of-00006.safetensors:  40%|█▌  | 1.95G/4.90G [00:17<00:30, 97.1MB/s]
#
#
#
#
# model-00006-of-00006.safetensors:  40%|█▌  | 2.01G/4.99G [00:17<00:35, 84.8MB/s]
# model-00001-of-00006.safetensors:  58%|██▉  | 2.88G/4.93G [00:17<00:19, 105MB/s]
#
# model-00002-of-00006.safetensors:  58%|██▎ | 2.89G/4.95G [00:17<00:23, 89.5MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:  45%|█▊  | 2.15G/4.77G [00:18<00:39, 65.7MB/s]
#
#
# model-00003-of-00006.safetensors:  41%|█▋  | 2.02G/4.90G [00:18<00:32, 89.8MB/s]
# model-00001-of-00006.safetensors:  60%|██▍ | 2.95G/4.93G [00:18<00:21, 94.0MB/s]
#
# model-00002-of-00006.safetensors:  60%|██▍ | 2.96G/4.95G [00:18<00:24, 83.3MB/s]
#
#
#
# model-00005-of-00006.safetensors:  58%|██▎ | 2.76G/4.77G [00:18<00:21, 92.5MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:  46%|█▊  | 2.22G/4.77G [00:18<00:30, 82.6MB/s]
#
#
#
#
# model-00006-of-00006.safetensors:  42%|█▋  | 2.08G/4.99G [00:18<00:39, 73.9MB/s]
# model-00001-of-00006.safetensors:  63%|███▏ | 3.08G/4.93G [00:18<00:13, 142MB/s]
#
# model-00002-of-00006.safetensors:  62%|███  | 3.09G/4.95G [00:18<00:14, 131MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:  48%|██▍  | 2.28G/4.77G [00:18<00:23, 104MB/s]
# model-00001-of-00006.safetensors:  64%|███▏ | 3.15G/4.93G [00:19<00:11, 156MB/s]
#
# model-00002-of-00006.safetensors:  65%|███▎ | 3.22G/4.95G [00:19<00:09, 180MB/s]
#
#
# model-00003-of-00006.safetensors:  42%|█▋  | 2.08G/4.90G [00:19<00:31, 89.8MB/s]
#
#
#
# model-00005-of-00006.safetensors:  59%|██▎ | 2.82G/4.77G [00:19<00:21, 91.3MB/s]
#
#
# model-00003-of-00006.safetensors:  44%|██▏  | 2.15G/4.90G [00:19<00:25, 109MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:  49%|██▍  | 2.35G/4.77G [00:19<00:22, 107MB/s]
#
#
#
#
# model-00006-of-00006.safetensors:  43%|█▋  | 2.15G/4.99G [00:19<00:36, 76.9MB/s]
# model-00001-of-00006.safetensors:  65%|███▎ | 3.22G/4.93G [00:19<00:11, 151MB/s]
#
# model-00002-of-00006.safetensors:  66%|███▎ | 3.29G/4.95G [00:19<00:09, 169MB/s]
#
#
# model-00003-of-00006.safetensors:  45%|██▎  | 2.22G/4.90G [00:19<00:20, 132MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:  51%|██▌  | 2.42G/4.77G [00:19<00:17, 131MB/s]
#
#
#
# model-00005-of-00006.safetensors:  61%|██▍ | 2.89G/4.77G [00:19<00:19, 98.3MB/s]
#
#
# model-00003-of-00006.safetensors:  47%|██▎  | 2.28G/4.90G [00:19<00:17, 151MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:  53%|██▋  | 2.55G/4.77G [00:19<00:11, 197MB/s]
#
#
#
#
# model-00006-of-00006.safetensors:  46%|██▎  | 2.28G/4.99G [00:20<00:24, 112MB/s]
#
#
#
# model-00005-of-00006.safetensors:  63%|███▏ | 3.03G/4.77G [00:20<00:12, 140MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:  56%|██▊  | 2.68G/4.77G [00:20<00:08, 234MB/s]
#
#
#
#
# model-00006-of-00006.safetensors:  48%|██▍  | 2.42G/4.99G [00:20<00:17, 150MB/s]
# model-00001-of-00006.safetensors:  68%|███▍ | 3.35G/4.93G [00:20<00:10, 145MB/s]
#
# model-00002-of-00006.safetensors:  69%|███▍ | 3.42G/4.95G [00:20<00:09, 154MB/s]
#
#
#
# model-00005-of-00006.safetensors:  65%|███▏ | 3.09G/4.77G [00:20<00:11, 147MB/s]
#
#
# model-00003-of-00006.safetensors:  49%|██▍  | 2.42G/4.90G [00:20<00:15, 164MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:  58%|██▉  | 2.75G/4.77G [00:20<00:08, 226MB/s]
#
#
#
#
# model-00006-of-00006.safetensors:  50%|██▍  | 2.48G/4.99G [00:20<00:15, 161MB/s]
#
# model-00002-of-00006.safetensors:  70%|███▌ | 3.49G/4.95G [00:20<00:08, 166MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:  59%|██▉  | 2.82G/4.77G [00:20<00:08, 229MB/s]
#
#
#
#
# model-00006-of-00006.safetensors:  51%|██▌  | 2.55G/4.99G [00:21<00:13, 175MB/s]
# model-00001-of-00006.safetensors:  69%|███▍ | 3.42G/4.93G [00:21<00:11, 136MB/s]
#
#
# model-00003-of-00006.safetensors:  52%|██▌  | 2.55G/4.90G [00:21<00:13, 168MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:  60%|███  | 2.89G/4.77G [00:21<00:09, 197MB/s]
# model-00001-of-00006.safetensors:  71%|███▌ | 3.49G/4.93G [00:21<00:10, 137MB/s]
#
# model-00002-of-00006.safetensors:  73%|███▋ | 3.63G/4.95G [00:22<00:09, 137MB/s]
#
#
#
# model-00005-of-00006.safetensors:  68%|███▍ | 3.23G/4.77G [00:22<00:13, 115MB/s]
#
#
# model-00003-of-00006.safetensors:  53%|██▋  | 2.62G/4.90G [00:22<00:16, 139MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:  63%|███▏ | 3.02G/4.77G [00:22<00:09, 185MB/s]
#
#
#
#
# model-00006-of-00006.safetensors:  55%|██▊  | 2.75G/4.99G [00:23<00:21, 105MB/s]
# model-00001-of-00006.safetensors:  72%|██▉ | 3.55G/4.93G [00:23<00:19, 72.5MB/s]
#
#
#
# model-00005-of-00006.safetensors:  69%|██▊ | 3.29G/4.77G [00:23<00:18, 81.9MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:  65%|███▏ | 3.09G/4.77G [00:23<00:16, 101MB/s]
# model-00001-of-00006.safetensors:  73%|██▉ | 3.62G/4.93G [00:24<00:14, 89.4MB/s]
#
# model-00002-of-00006.safetensors:  75%|██▉ | 3.69G/4.95G [00:24<00:15, 83.9MB/s]
#
#
#
# model-00005-of-00006.safetensors:  70%|██▊ | 3.36G/4.77G [00:24<00:14, 97.3MB/s]
#
#
# model-00003-of-00006.safetensors:  55%|██▏ | 2.68G/4.90G [00:24<00:27, 80.7MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:  66%|███▎ | 3.15G/4.77G [00:24<00:13, 118MB/s]
# model-00001-of-00006.safetensors:  76%|███▊ | 3.76G/4.93G [00:24<00:08, 139MB/s]
#
# model-00002-of-00006.safetensors:  77%|███▊ | 3.83G/4.95G [00:24<00:09, 122MB/s]
#
#
#
# model-00005-of-00006.safetensors:  72%|███▌ | 3.43G/4.77G [00:24<00:11, 114MB/s]
#
#
# model-00003-of-00006.safetensors:  56%|██▏ | 2.75G/4.90G [00:24<00:22, 96.9MB/s]
# model-00001-of-00006.safetensors:  77%|███▊ | 3.82G/4.93G [00:24<00:07, 147MB/s]
#
# model-00002-of-00006.safetensors:  80%|███▉ | 3.96G/4.95G [00:24<00:06, 159MB/s]
#
#
# model-00003-of-00006.safetensors:  59%|██▉  | 2.89G/4.90G [00:24<00:14, 138MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:  69%|███▍ | 3.29G/4.77G [00:24<00:10, 141MB/s]
#
#
#
#
# model-00006-of-00006.safetensors:  59%|██▉  | 2.95G/4.99G [00:24<00:16, 123MB/s]
# model-00001-of-00006.safetensors:  80%|████ | 3.96G/4.93G [00:25<00:04, 198MB/s]
#
# model-00002-of-00006.safetensors:  81%|████ | 4.03G/4.95G [00:25<00:05, 166MB/s]
#
#
#
# model-00005-of-00006.safetensors:  73%|███▋ | 3.49G/4.77G [00:25<00:11, 109MB/s]
#
#
# model-00003-of-00006.safetensors:  60%|███  | 2.95G/4.90G [00:25<00:12, 152MB/s]
#
#
#
#
# model-00006-of-00006.safetensors:  61%|███  | 3.02G/4.99G [00:25<00:14, 134MB/s]
#
# model-00002-of-00006.safetensors:  83%|████▏| 4.10G/4.95G [00:25<00:04, 178MB/s]
#
#
#
# model-00005-of-00006.safetensors:  75%|███▋ | 3.56G/4.77G [00:25<00:09, 128MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:  70%|███▌ | 3.35G/4.77G [00:25<00:10, 135MB/s]
#
#
#
#
# model-00006-of-00006.safetensors:  62%|███  | 3.09G/4.99G [00:25<00:13, 146MB/s]
# model-00001-of-00006.safetensors:  83%|████▏| 4.09G/4.93G [00:25<00:03, 212MB/s]
#
#
# model-00003-of-00006.safetensors:  62%|███  | 3.02G/4.90G [00:25<00:13, 141MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:  72%|███▌ | 3.42G/4.77G [00:25<00:09, 146MB/s]
# model-00001-of-00006.safetensors:  84%|████▏| 4.16G/4.93G [00:25<00:03, 209MB/s]
#
#
#
# model-00005-of-00006.safetensors:  77%|███▊ | 3.70G/4.77G [00:26<00:06, 154MB/s]
#
#
# model-00003-of-00006.safetensors:  63%|███▏ | 3.09G/4.90G [00:26<00:12, 151MB/s]
#
# model-00002-of-00006.safetensors:  84%|████▏| 4.16G/4.95G [00:26<00:06, 130MB/s]
#
#
#
# model-00005-of-00006.safetensors:  80%|████ | 3.83G/4.77G [00:26<00:04, 204MB/s]
#
#
# model-00003-of-00006.safetensors:  64%|███▏ | 3.15G/4.90G [00:26<00:10, 164MB/s]
#
#
#
#
# model-00006-of-00006.safetensors:  65%|███▏ | 3.22G/4.99G [00:26<00:12, 143MB/s]
# model-00001-of-00006.safetensors:  86%|████▎| 4.23G/4.93G [00:26<00:04, 173MB/s]
#
# model-00002-of-00006.safetensors:  87%|████▎| 4.30G/4.95G [00:26<00:03, 184MB/s]
#
#
#
# model-00005-of-00006.safetensors:  83%|████▏| 3.96G/4.77G [00:26<00:03, 256MB/s]
#
#
# model-00003-of-00006.safetensors:  66%|███▎ | 3.22G/4.90G [00:26<00:09, 180MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:  76%|███▊ | 3.62G/4.77G [00:26<00:06, 176MB/s]
#
#
#
#
# model-00006-of-00006.safetensors:  66%|███▎ | 3.29G/4.99G [00:26<00:10, 156MB/s]
#
# model-00002-of-00006.safetensors:  88%|████▍| 4.36G/4.95G [00:26<00:03, 188MB/s]
#
#
#
# model-00005-of-00006.safetensors:  86%|████▎| 4.10G/4.77G [00:26<00:02, 288MB/s]
#
#
# model-00003-of-00006.safetensors:  67%|███▎ | 3.29G/4.90G [00:27<00:08, 182MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:  77%|███▊ | 3.69G/4.77G [00:27<00:06, 177MB/s]
# model-00001-of-00006.safetensors:  87%|████▎| 4.30G/4.93G [00:27<00:04, 147MB/s]
#
# model-00002-of-00006.safetensors:  89%|████▍| 4.43G/4.95G [00:27<00:02, 185MB/s]
#
#
#
# model-00005-of-00006.safetensors:  89%|████▍| 4.23G/4.77G [00:27<00:01, 310MB/s]
#
#
# model-00003-of-00006.safetensors:  68%|███▍ | 3.35G/4.90G [00:27<00:08, 183MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:  79%|███▉ | 3.75G/4.77G [00:28<00:08, 118MB/s]
#
#
#
#
# model-00006-of-00006.safetensors:  67%|██▋ | 3.35G/4.99G [00:28<00:16, 96.6MB/s]
#
# model-00002-of-00006.safetensors:  91%|████▌| 4.50G/4.95G [00:28<00:03, 119MB/s]
# model-00001-of-00006.safetensors:  88%|████▍| 4.36G/4.93G [00:28<00:05, 102MB/s]
#
#
# model-00003-of-00006.safetensors:  70%|███▍ | 3.42G/4.90G [00:28<00:12, 117MB/s]
#
#
#
# model-00005-of-00006.safetensors:  91%|████▌| 4.36G/4.77G [00:28<00:02, 190MB/s]
#
#
#
#
# model-00006-of-00006.safetensors:  69%|███▍ | 3.42G/4.99G [00:28<00:15, 101MB/s]
#
# model-00002-of-00006.safetensors:  92%|████▌| 4.56G/4.95G [00:28<00:03, 119MB/s]
# model-00001-of-00006.safetensors:  90%|████▍| 4.43G/4.93G [00:29<00:04, 104MB/s]
#
#
#
#
# model-00006-of-00006.safetensors:  71%|███▌ | 3.56G/4.99G [00:29<00:09, 156MB/s]
#
#
#
# model-00005-of-00006.safetensors:  93%|████▋| 4.43G/4.77G [00:29<00:01, 171MB/s]
#
# model-00002-of-00006.safetensors:  95%|████▋| 4.70G/4.95G [00:29<00:01, 177MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:  81%|████ | 3.89G/4.77G [00:29<00:07, 120MB/s]
#
#
#
#
# model-00006-of-00006.safetensors:  73%|███▋ | 3.62G/4.99G [00:29<00:08, 164MB/s]
#
#
# model-00003-of-00006.safetensors:  71%|██▊ | 3.49G/4.90G [00:29<00:15, 94.0MB/s]
# model-00001-of-00006.safetensors:  93%|████▋| 4.56G/4.93G [00:29<00:02, 140MB/s]
#
#
#
# model-00005-of-00006.safetensors:  94%|████▋| 4.50G/4.77G [00:29<00:01, 168MB/s]
#
# model-00002-of-00006.safetensors:  96%|████▊| 4.76G/4.95G [00:29<00:01, 170MB/s]
#
#
# model-00003-of-00006.safetensors:  74%|███▋ | 3.62G/4.90G [00:29<00:08, 147MB/s]
# model-00001-of-00006.safetensors:  95%|████▊| 4.70G/4.93G [00:29<00:01, 193MB/s]
#
#
# model-00003-of-00006.safetensors:  75%|███▊ | 3.69G/4.90G [00:29<00:06, 177MB/s]
#
#
#
#
# model-00006-of-00006.safetensors:  74%|███▋ | 3.69G/4.99G [00:29<00:08, 154MB/s]
# model-00001-of-00006.safetensors:  97%|████▊| 4.76G/4.93G [00:30<00:00, 214MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:  84%|████▏| 4.02G/4.77G [00:30<00:05, 137MB/s]
#
#
# model-00003-of-00006.safetensors:  77%|███▊ | 3.75G/4.90G [00:30<00:05, 202MB/s]
#
#
#
#
# model-00006-of-00006.safetensors:  76%|███▊ | 3.78G/4.99G [00:30<00:06, 194MB/s]
# model-00001-of-00006.safetensors:  97%|████▊| 4.80G/4.93G [00:30<00:00, 211MB/s]
#
#
#
# model-00005-of-00006.safetensors:  96%|████▊| 4.57G/4.77G [00:30<00:01, 145MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:  86%|████▎| 4.09G/4.77G [00:30<00:04, 149MB/s]
# model-00001-of-00006.safetensors:  99%|████▉| 4.87G/4.93G [00:30<00:00, 219MB/s]
#
# model-00001-of-00006.safetensors: 100%|█████| 4.93G/4.93G [00:30<00:00, 161MB/s]
# Download complete. Moving file to /models/RedHatAI/phi-4/model-00001-of-00006.safetensors
# Fetching 20 files:  50%|████████████            | 10/20 [00:31<00:43,  4.39s/it]
#
#
# model-00003-of-00006.safetensors:  78%|███▉ | 3.83G/4.90G [00:30<00:06, 177MB/s]
#
#
#
#
# model-00006-of-00006.safetensors:  78%|███▉ | 3.91G/4.99G [00:30<00:05, 210MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:  87%|████▎| 4.16G/4.77G [00:30<00:03, 156MB/s]
#
#
# model-00003-of-00006.safetensors:  79%|███▉ | 3.90G/4.90G [00:30<00:05, 197MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:  89%|████▍| 4.22G/4.77G [00:30<00:03, 180MB/s]
#
#
# model-00003-of-00006.safetensors:  81%|████ | 3.96G/4.90G [00:31<00:04, 230MB/s]
#
#
#
#
# model-00006-of-00006.safetensors:  80%|███▉ | 3.98G/4.99G [00:31<00:05, 199MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:  92%|████▌| 4.37G/4.77G [00:31<00:01, 266MB/s]
#
#
# model-00003-of-00006.safetensors:  82%|████ | 4.03G/4.90G [00:31<00:03, 270MB/s]
#
#
#
#
# model-00006-of-00006.safetensors:  81%|████ | 4.05G/4.99G [00:31<00:04, 223MB/s]
#
#
# model-00003-of-00006.safetensors:  85%|████▏| 4.17G/4.90G [00:31<00:01, 394MB/s]
#
#
#
#
# model-00006-of-00006.safetensors:  84%|████▏| 4.18G/4.99G [00:31<00:02, 323MB/s]
#
#
# model-00003-of-00006.safetensors:  86%|████▎| 4.23G/4.90G [00:31<00:01, 377MB/s]
#
#
#
#
# model-00006-of-00006.safetensors:  87%|████▎| 4.32G/4.99G [00:31<00:01, 407MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:  93%|████▋| 4.44G/4.77G [00:31<00:01, 223MB/s]
#
#
#
# model-00005-of-00006.safetensors:  99%|████▉| 4.70G/4.77G [00:31<00:00, 124MB/s]
#
# model-00002-of-00006.safetensors: 100%|█████| 4.95G/4.95G [00:31<00:00, 156MB/s]
# Download complete. Moving file to /models/RedHatAI/phi-4/model-00002-of-00006.safetensors
# Fetching 20 files:  55%|█████████████▏          | 11/20 [00:32<00:34,  3.84s/it]
#
#
# model-00005-of-00006.safetensors: 100%|█████| 4.77G/4.77G [00:31<00:00, 150MB/s]
# Download complete. Moving file to /models/RedHatAI/phi-4/model-00005-of-00006.safetensors
#
#
#
#
#
# model-00006-of-00006.safetensors:  92%|████▌| 4.58G/4.99G [00:31<00:00, 689MB/s]
#
#
# model-00003-of-00006.safetensors:  93%|████▋| 4.57G/4.90G [00:32<00:00, 351MB/s]
#
#
# model-00003-of-00006.safetensors:  95%|████▋| 4.63G/4.90G [00:33<00:01, 176MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:  94%|███▊| 4.50G/4.77G [00:33<00:03, 85.3MB/s]
#
#
#
#
# model-00006-of-00006.safetensors:  95%|████▋| 4.72G/4.99G [00:34<00:01, 161MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:  97%|████▊| 4.64G/4.77G [00:34<00:01, 116MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors:  99%|████▉| 4.70G/4.77G [00:34<00:00, 138MB/s]
#
#
#
#
# model-00006-of-00006.safetensors:  97%|████▊| 4.85G/4.99G [00:34<00:00, 178MB/s]
#
#
# model-00003-of-00006.safetensors:  96%|████▊| 4.70G/4.90G [00:35<00:01, 106MB/s]
#
#
#
#
# model-00006-of-00006.safetensors: 100%|█████| 4.99G/4.99G [00:35<00:00, 141MB/s]
# Download complete. Moving file to /models/RedHatAI/phi-4/model-00006-of-00006.safetensors
# model-00003-of-00006.safetensors: 100%|█████| 4.90G/4.90G [00:35<00:00, 138MB/s]
# Download complete. Moving file to /models/RedHatAI/phi-4/model-00003-of-00006.safetensors
# Fetching 20 files:  60%|██████████████▍         | 12/20 [00:36<00:30,  3.82s/it]
#
#
#
#
#
# model-00004-of-00006.safetensors:  99%|████▉| 4.70G/4.77G [00:48<00:00, 138MB/s]
#
#
#
#
#
# model-00004-of-00006.safetensors: 100%|████| 4.77G/4.77G [00:54<00:00, 87.8MB/s]
# Download complete. Moving file to /models/RedHatAI/phi-4/model-00004-of-00006.safetensors
# Fetching 20 files: 100%|████████████████████████| 20/20 [00:55<00:00,  2.77s/it]
# /models/RedHatAI/phi-4

# %% [markdown]
# ## Run vLLM Server - Foreground
#
# Run this cell to start the server in foreground mode. The server will run until you interrupt the kernel.

# %%
served_model_name = "meta-llama/Llama-3.3-70B-Instruct"
num_gpus="4"
max_model_len="16000"

# %%
# !vllm serve $model_dir \
    --host 0.0.0.0 \
    --port 8000 \
    --served-model-name $served_model_name \
    --tensor-parallel-size=$num_gpus \
    --distributed-executor-backend=mp \
    --max-model-len=$max_model_len

# %% [markdown]
# Test with a small model

# %%
# !vllm serve Qwen/Qwen2.5-0.5B-Instruct \
#     --host 0.0.0.0 \
#     --port 8000 \
#     --max-model-len 2048
